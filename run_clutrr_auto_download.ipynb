# %% [markdown]
# # ARM on CLUTRR: Real Benchmark with Auto Download
#
# This notebook runs ARM against a direct attention-memory baseline on CLUTRR. CLUTRR is downloaded automatically through Hugging Face `datasets`.

# %%
# !git clone --depth 1 https://github.com/godsonj64/ARM.git
# %cd ARM
# !pip -q install -r requirements.txt

# %%
# !python benchmarks/clutrr_compare.py --epochs 8 --max-train 12000 --max-eval 3000 --device cuda

# %% [markdown]
# Outputs are written to `benchmark_results/clutrr_compare.json` and `benchmark_results/clutrr_learning_curves.png`.
