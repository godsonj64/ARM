# %% [markdown]
# # ARM Benchmarks: ARM vs Direct Attention
#
# This Colab notebook clones the ARM repository and runs benchmark scripts comparing Algebraic Resonance Memory against a direct attention-memory baseline.

# %%
# !git clone --depth 1 https://github.com/godsonj64/ARM.git
# %cd ARM
# !pip -q install -r requirements.txt

# %% [markdown]
# ## Synthetic cyclic benchmark
#
# Fast benchmark based on the original fan-state idea.

# %%
# !python benchmarks/synthetic_compare.py --epochs 10 --device cuda

# %% [markdown]
# ## CLUTRR real-dataset benchmark
#
# This downloads CLUTRR from Hugging Face and compares ARM against direct attention on kinship-relation reasoning.

# %%
# !python benchmarks/clutrr_compare.py --epochs 6 --device cuda
