# %% [markdown]
# # Algebraic Resonance Memory on bAbI
#
# This notebook runs ARM on the official bAbI multi-hop memory QA benchmark.

# %%
# !pip -q install matplotlib
# !git clone -q https://github.com/godsonj64/ARM.git
# %run ARM/arm_babi_colab.py
