# %% [markdown]
# # Algebraic Resonance Memory (ARM)
#
# This notebook downloads and runs the full PyTorch ARM implementation from this repository.

# %%
# !pip -q install matplotlib
# !wget -q -O arm_colab_runnable.py https://raw.githubusercontent.com/godsonj64/ARM/main/arm_colab_runnable.py
# %run arm_colab_runnable.py
