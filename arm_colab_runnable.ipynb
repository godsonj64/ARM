# %% [markdown]
# # Algebraic Resonance Memory on CLUTRR
#
# This Colab notebook installs dependencies, downloads the real-dataset ARM benchmark from GitHub, and trains ARM on CLUTRR kinship-relation reasoning.

# %%
# !pip -q install -r https://raw.githubusercontent.com/godsonj64/ARM/main/requirements.txt
# !wget -q -O arm_clutrr_colab.py https://raw.githubusercontent.com/godsonj64/ARM/main/arm_clutrr_colab.py
# %run arm_clutrr_colab.py
