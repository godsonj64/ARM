# %% [markdown]
# # ARM Real Benchmark: CLUTRR Auto-Download
#
# This notebook clones the ARM repository and runs the real CLUTRR benchmark. The dataset is downloaded automatically through Hugging Face `datasets`.

# %%
# !git clone --depth 1 https://github.com/godsonj64/ARM.git
# %cd ARM
# !pip -q install -r requirements.txt

# %% [markdown]
# ## CLUTRR kinship-reasoning benchmark
#
# This compares ARM against a direct attention-memory baseline on real relational reasoning data.

# %%
# !python benchmarks/clutrr_compare.py --epochs 8 --device cuda
